# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/thispc/Documents/Orders (Global Superstore)_Migrated Data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/28/xzg4vjpj3gj6x32fqvxyzd440000gn/T/ipykernel_1547/3779166582.py in <module>
# ----> 1 df = pd.read_csv(r'/Users/thispc/Documents/Orders (Global Superstore)_Migrated Data.csv')
#       2
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv(
    r'/Users/thispc/Documents/Orders (Global Superstore)_Migrated Data.csv',
    encoding='utf-16',
    delimiter='\t'  # Adjust to the correct delimiter
)

# %%
df
# Out:
#               Category         City        Country Customer ID         Market  \
# 0      Office Supplies     Budapest        Hungary     AT-7352           EMEA
# 1      Office Supplies    Stockholm         Sweden   EM-141402             EU
# 2      Office Supplies  Constantine        Algeria   TB-112801         Africa
# 3            Furniture  Wagga Wagga      Australia   JH-159851           APAC
# 4      Office Supplies  Wagga Wagga      Australia   JH-159851           APAC
# ...                ...          ...            ...         ...            ...
# 51285  Office Supplies     Columbus  United States   CC-124304  North America
# 51286       Technology     Surabaya      Indonesia   MH-177851           APAC
# 51287  Office Supplies      Shantou          China   KM-162251           APAC
# 51288  Office Supplies      Shantou          China   KM-162251           APAC
# 51289       Technology      Shantou          China   KM-162251           APAC
#
# ...

# %%
df2 = pd.read_csv('/Users/thispc/Documents/Sales by Rep_Migrated Data.csv',encoding='utf-16',delimiter='\t')

# %%
df2
# Out:
#        Country         Deal ID     Sales Rep  Number of Records     Sales  \
# 0        Benin  US-2014-125213     Nona Balk                  1     6.540
# 1        Benin     AG-2012-170    Philip Fox                  1   198.210
# 2        Benin    BN-2014-9200    Philip Fox                  1  1187.160
# 3        Benin  CA-2012-101707    Philip Fox                  1   150.220
# 4        Benin  CA-2012-111458    Philip Fox                  1    50.000
# ...        ...             ...           ...                ...       ...
# 271950   Spain   IN-2014-61792  Mitch Webber                  1  4191.507
# 271951   Spain  MX-2012-100461  Mitch Webber                  1   148.800
# 271952   Spain  MX-2012-104276  Mitch Webber                  1    15.060
# 271953   Spain  MX-2012-134341  Mitch Webber                  1   385.420
# 271954   Spain  MX-2012-164007  Mitch Webber                  1    42.160
#
#         Year of Transaction Date
# 0                           2014
# ...

# %%
def word_count(sentences):
    sentences = sentences.replace('\n', ' ')
    word_count = {}
    char_count = {}
    words = sentences.split(' ')
    for word in words:
        if word in word_count:
            word_count[word] +=1
        else:
            word_count[word] = 1
        for char in word.strip():
            if char in char_count:
                char_count[char] +=1
            else:
                char_count[char] = 1 
    return word_count,char_count
    
    


sentences = """Operational Excellence Pillar

The operational excellence pillar focuses on running and monitoring systems, and continually improving processes and procedures. Key topics include automating changes, responding to events, and defining standards to manage daily operations."""
word,result = word_count(sentences)
print(result)
print(word)
